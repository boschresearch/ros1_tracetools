# %%
import sys
sys.path.append('/home/ingo/src/ros_ws/src/tracetools/src/tracing/')
import trace_pandas as tp
import pandas as pd
import numpy as np
from ros_mapping import map_roscpp
from pandas.tseries.offsets import Milli, Second


# %matplotlib inline

import matplotlib
matplotlib.style.use('ggplot')

# %%
basic_model=[
    ("local_costmap/obstacle_layer", "receipt_time"),
    ("local_costmap/obstacle_layer", "timestamp"),
    ("costs local_costmap/obstacle_layer", "timestamp"),
    ("local planner", "timestamp"),
    ("/navigation_velocity_smoother/raw_cmd_vel", "timestamp")
]
unsynced_model=[
    ("local_costmap/obstacle_layer", "receipt_time"),
    ("after tf scan local_costmap/obstacle_layer", "timestamp"),
    ("trigger update local_costmap", "timestamp"),
    ("local planner", "timestamp"),
    ("/navigation_velocity_smoother/raw_cmd_vel", "timestamp")
]

ext_model=[
    ("local_costmap/obstacle_layer", "receipt_time"),
    ("before tf scan local_costmap/obstacle_layer", "timestamp"),
    ("after tf scan local_costmap/obstacle_layer", "timestamp"),
    ("sensor sync", "timestamp"),
    ("trigger update local_costmap", "timestamp"),
    ("local planner", "timestamp"),
    ("/navigation_velocity_smoother/raw_cmd_vel", "timestamp")
]

def model_delays(trace_df, model, search_window=50):
    # extract data from input message traces
    elements=[]
    columns=[]
    have_names = False
    
    for message_name, attribute in model:
        es=trace_df.mtrace.query("message_name=='%s'" % message_name)[attribute]
        if(len(es) == 0):
            print("Warning: Could not find messages for %s" % message_name)
        elements.append(es)

    # compute delays between element entries and their respective successors from the next element
    timestamps=[]
    all_delays=[[] for i in range(1, len(elements))]
    afteriter = elements[0].iteritems()
    afteriter.__next__()
    for current, ne in zip(elements[0].iteritems(), afteriter):
        time, e = current
        _, time_next = ne
        timestamps.append(time)
        ts=e # initially should be receive time or equivalent
        name = "message stamp"
        for index, element in enumerate(elements[1:]):
            current_name = "%s-%s" % model[index+1]
            if not have_names:
                columns.append("%s -> %s" % (name, current_name))
                name = current_name
            subset=elements[index+1][ts:ts+Milli(300)]
            # see if we found something
            if len(subset) > 0 and subset[0] < time_next:
                delay=subset[0] - ts
                ts=subset[0]
            else:
                delay = pd.Timedelta(0)

            all_delays[index].append(delay)
        
        have_names = True

    df = pd.DataFrame({columns[i]: pd.Series(all_delays[i], index=timestamps) 
                        for i, e in enumerate(model[1:])}, 
                       columns=columns)
    # convert delays into milliseconds
    df/=1e6
    return df

def plot_delays(times,fname=None, **kwargs):
    times.astype(np.int64).plot.area(stacked=True, **kwargs)
    if fname is not None:
        matplotlib.pyplot.savefig(fname)

def plot_box(t, xlim=(0, 200), fname=None):
    ax=t.astype(np.int64).boxplot(vert=False, return_type='axes', showfliers=False)
    _=ax.set_xlim(xlim[0], xlim[1])
    if fname is not None:
        matplotlib.pyplot.savefig(fname)

# %%
trace2=tp.pickle2pd("/home/ingo/Data/2016/04/auto-20160425-105521.pickle", map_roscpp)

# %%
t=model_delays(trace2, model=basic_model)
plot_delays(t, figsize=(20, 6), ylim=(0, 300), title="indigo-devel@5810395cf6e (v1.12.4+CR)")

# %%
t.astype(np.int64).describe()
# Out:
#        message stamp -> local_costmap/obstacle_layer-timestamp  \
# count                                         217.000000
# mean                                           36.350230
# std                                            11.491016
# min                                             0.000000
# 25%                                            34.000000
# 50%                                            34.000000
# 75%                                            35.000000
# max                                            75.000000
#
#        local_costmap/obstacle_layer-timestamp -> costs local_costmap/obstacle_layer-timestamp  \
# count                                                217
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    0
#
#        costs local_costmap/obstacle_layer-timestamp -> local planner-timestamp  \
# count                                         217.000000
# mean                                           48.981567
# std                                            70.963081
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                           157.000000
# max                                           158.000000
#
#        local planner-timestamp -> /navigation_velocity_smoother/raw_cmd_vel-timestamp
# count                                         217.000000
# mean                                           14.714286
# std                                            19.319953
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                            36.000000
# max                                           158.000000

# %%
df_upstream_5=tp.pickle2pd("/home/ingo/Temp/ita-default-22423-20160622-135450.pickle", map_roscpp)

# %%
df_synced_5=tp.pickle2pd("/home/ingo/Temp/ita-local_costmap_no_update-24109-20160622-143249.pickle", map_roscpp)

# %%
df_async_125=tp.pickle2pd("/home/ingo/Temp/ita-ita-Async-at-sensor-rate-18186-20160622-144924.pickle", map_roscpp)

# %%
#set(df_upstream_5.mtrace['message_name'])
t=model_delays(df_upstream_5, unsynced_model)
t_s=model_delays(df_synced_5, unsynced_model)

# %%
t_125=model_delays(df_async_125, unsynced_model)
t_125.astype(np.int64).describe()
# Out:
#        message stamp -> after tf scan local_costmap/obstacle_layer-timestamp  \
# count                                        1149.000000
# mean                                            3.967798
# std                                             0.384600
# min                                             0.000000
# 25%                                             4.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             6.000000
#
#        after tf scan local_costmap/obstacle_layer-timestamp -> trigger update local_costmap-timestamp  \
# count                                        1149.000000
# mean                                           10.844212
# std                                            26.494413
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            76.000000
#
#        trigger update local_costmap-timestamp -> local planner-timestamp  \
# count                                        1149.000000
# mean                                           32.123586
# std                                            21.195959
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            42.000000
# 75%                                            51.000000
# max                                            52.000000
#
#        local planner-timestamp -> /navigation_velocity_smoother/raw_cmd_vel-timestamp
# count                                        1149.000000
# mean                                            5.982594
# std                                             9.017678
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                            52.000000

# %%
t.astype(np.int64).describe()
# Out:
#        message stamp -> after tf scan local_costmap/obstacle_layer-timestamp  \
# count                                        1824.000000
# mean                                            4.334430
# std                                             1.067651
# min                                             2.000000
# 25%                                             4.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             7.000000
#
#        after tf scan local_costmap/obstacle_layer-timestamp -> trigger update local_costmap-timestamp  \
# count                                        1824.000000
# mean                                           45.725329
# std                                            28.389457
# min                                             0.000000
# 25%                                            34.000000
# 50%                                            41.000000
# 75%                                            74.000000
# max                                           114.000000
#
#        trigger update local_costmap-timestamp -> local planner-timestamp  \
# count                                        1824.000000
# mean                                           30.297149
# std                                            29.399316
# min                                             0.000000
# 25%                                             5.000000
# 50%                                            18.000000
# 75%                                            59.000000
# max                                           187.000000
#
#        local planner-timestamp -> /navigation_velocity_smoother/raw_cmd_vel-timestamp
# count                                        1824.000000
# mean                                            4.484649
# std                                             3.410607
# min                                             0.000000
# 25%                                             5.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                            87.000000

# %%
t_s.astype(np.int64).describe()
# Out:
#        message stamp -> after tf scan local_costmap/obstacle_layer-timestamp  \
# count                                        4382.000000
# mean                                            4.002054
# std                                             0.445368
# min                                             0.000000
# 25%                                             4.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             6.000000
#
#        after tf scan local_costmap/obstacle_layer-timestamp -> trigger update local_costmap-timestamp  \
# count                                        4382.000000
# mean                                            0.168873
# std                                             2.512831
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            66.000000
#
#        trigger update local_costmap-timestamp -> local planner-timestamp  \
# count                                        4382.000000
# mean                                            0.509356
# std                                             0.509915
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             4.000000
#
#        local planner-timestamp -> /navigation_velocity_smoother/raw_cmd_vel-timestamp
# count                                        4382.000000
# mean                                            4.168416
# std                                             1.779933
# min                                             0.000000
# 25%                                             4.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                            18.000000

# %%
plot_delays(t, fname="move_base-stock.png", figsize=(20, 6), ylim=(0, 300), title="indigo-devel v.12.11 5 times")

# %%
matplotlib.pyplot.savefig("move_base-1.12.11, stock.png")

# %%
plot_delays(t_125, fname="move_base-1.12.11@12.5Hz.svg", figsize=(20, 6), ylim=(0, 300), title="indigo-devel v.12.11 at 12.5 Hz")

# %%
plot_delays(t_s, fname="rose-move_base.svg", figsize=(20, 6), ylim=(0, 300), title="indigo-devel SYNC v.12.11 5 times")

# %%
plot_box(t, fname="move_base-stock-boxes.svg")

# %%
ax=t_125.astype(np.int64).boxplot(vert=False, return_type='axes', showfliers=False)
_=ax.set_xlim(0, 200)

# %%
ax=t_s.astype(np.int64).boxplot(vert=False, return_type='axes')
_=ax.set_xlim(0, 200)

# %%
t=model_delays(df_synced, model=basic_model)
plot_delays(t, figsize=(20, 6), ylim=(0, 300), title="indigo-devel sequential update+dirty tracking")

# %%
t.astype(np.int64).describe()
# Out:
#        message stamp -> local_costmap/obstacle_layer-timestamp  \
# count                                         1000.00000
# mean                                            15.34100
# std                                             11.68543
# min                                              0.00000
# 25%                                              8.00000
# 50%                                             10.00000
# 75%                                             28.00000
# max                                             37.00000
#
#        local_costmap/obstacle_layer-timestamp -> costs local_costmap/obstacle_layer-timestamp  \
# count                                               1000
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    0
#
#        costs local_costmap/obstacle_layer-timestamp -> local planner-timestamp  \
# count                                               1000
# mean                                                   0
# std                                                    0
# min                                                    0
# 25%                                                    0
# 50%                                                    0
# 75%                                                    0
# max                                                    0
#
#        local planner-timestamp -> /navigation_velocity_smoother/raw_cmd_vel-timestamp
# count                                        1000.000000
# mean                                            3.506000
# std                                             2.209716
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             9.000000

# %%
t.head()
# Out:
#                                message stamp -> after tf scan local_costmap/obstacle_layer-timestamp  \
# 2016-06-22 11:54:59.821289317                                    00:00:00.000000
# 2016-06-22 11:55:00.021362595                                    00:00:00.000000
# 2016-06-22 11:55:00.221203718                                    00:00:00.000000
# 2016-06-22 11:55:00.421223034                                    00:00:00.000000
# 2016-06-22 11:55:00.621258915                                    00:00:00.000000
#
#                                after tf scan local_costmap/obstacle_layer-timestamp -> trigger update local_costmap-timestamp  \
# 2016-06-22 11:54:59.821289317                                    00:00:00.000000
# 2016-06-22 11:55:00.021362595                                    00:00:00.000000
# 2016-06-22 11:55:00.221203718                                    00:00:00.000000
# 2016-06-22 11:55:00.421223034                                    00:00:00.000000
# 2016-06-22 11:55:00.621258915                                    00:00:00.000000
#
#                                trigger update local_costmap-timestamp -> local planner-timestamp  \
# 2016-06-22 11:54:59.821289317                                             0 days
# 2016-06-22 11:55:00.021362595                                             0 days
# 2016-06-22 11:55:00.221203718                                             0 days
# 2016-06-22 11:55:00.421223034                                             0 days
# 2016-06-22 11:55:00.621258915                                             0 days
#
#                                local planner-timestamp -> /navigation_velocity_smoother/raw_cmd_vel-timestamp
# 2016-06-22 11:54:59.821289317                                             0 days
# 2016-06-22 11:55:00.021362595                                             0 days
# 2016-06-22 11:55:00.221203718                                             0 days
# 2016-06-22 11:55:00.421223034                                             0 days
# 2016-06-22 11:55:00.621258915                                             0 days

# %%
with_tf_model=[
    ("local_costmap/obstacle_layer", "receipt_time"),
    ("before tf local_costmap/obstacle_layer", "timestamp"),
    ("after tf local_costmap/obstacle_layer", "timestamp"),
    ("sensor sync", "timestamp"),
    ("trigger update local_costmap", "timestamp"),
    ("local planner", "timestamp"),
    ("/navigation_velocity_smoother/raw_cmd_vel", "timestamp")
]

    
df_with_tf=tp.pickle2pd("/home/ingo/Temp/turtlebot-run-14643-local_costmap_no_update-20160617-153603.pickle", map_roscpp)
time_maxage=model_delays(df_with_tf, with_tf_model)
#print(time_maxage.columns, time_maxage['execute cycle-timestamp'].max())
time_maxage/=1e6
time_maxage.astype(np.int64).plot.area(stacked=True, figsize=(20,6), ylim=(0, 100))

# %%
with_source_model=[
    ("local_costmap/obstacle_layer", "receipt_time"),
    ("before tf scan local_costmap/obstacle_layer", "timestamp"),
    ("after tf scan local_costmap/obstacle_layer", "timestamp"),
    ("sensor sync", "timestamp"),
    ("trigger update local_costmap", "timestamp"),
    ("local planner", "timestamp"),
    ("/navigation_velocity_smoother/raw_cmd_vel", "timestamp")
]
df=tp.pickle2pd("/home/ingo/Temp/turtlebot-run-19783-local_costmap_no_update-20160621-123535.pickle", map_roscpp)

# %%
plot_delays(model_delays(df, with_source_model), figsize=(20,8), ylim=(0,100), title="feature/minimal-tf 21. Juni 2016")

# %%
plan=df.mtrace.query("message_name=='local planner'")['timestamp']
(plan - plan.shift()).describe()
sent=model_delays(df, with_source_model)['message stamp -> before tf scan local_costmap/obstacle_layer-timestamp']
sent.astype(np.int64).describe()
# Out:
# count    427.000000
# mean      11.761124
# std       11.112489
# min        0.000000
# 25%        0.000000
# 50%        9.000000
# 75%       20.000000
# max       37.000000
# Name: message stamp -> before tf scan local_costmap/obstacle_layer-timestamp, dtype: float64

# %%
#df.invocations['duration']/=1e6
df.invocations['duration']*=1e3

# %%
df.invocations.query("task_id==26509").groupby("callback").agg({'duration': np.mean})\
                                                               .merge(df.functions, how='outer', left_index=True, 
                                                                      right_on='callback').sort_values(by='duration', ascending=False)
# Out:
#                 duration  callback  \
# 26509 12864560  0.258837  12864560
#       12864560  0.258837  12864560
#       17707136  0.257397  17707136
#       13100048  0.241163  13100048
#       13100048  0.241163  13100048
#       28362640  0.239813  28362640
#       17707184  0.052978  17707184
#       17707184  0.052978  17707184
#       17705200  0.051201  17705200
#       13100384  0.029566  13100384
#       13100384  0.029566  13100384
#       13099584  0.028050  13099584
#       17693520  0.006026  17693520
#       17693520  0.006026  17693520
#       13100320  0.005094  13100320
#       13100320  0.005094  13100320
#       17698992  0.004319  17698992
#       17698992  0.004319  17698992
#       17696512  0.003902  17696512
#       13107216  0.003781  13107216
#       13101888  0.003681  13101888
#       13101888  0.003681  13101888
#       13049328  0.003449  13049328
#       13049328  0.003449  13049328
#       17699584  0.002893  17699584
#       17699584  0.002893  17699584
#       17699040  0.002549  17699040
#       17699312  0.002236  17699312
#       13107168  0.002082  13107168
#       17705136  0.001586  17705136
# ...                  ...       ...
#       28363232       NaN  28363232
#       13110496       NaN  13110496
#       13110496       NaN  13110496
#       13110704       NaN  13110704
#       13110656       NaN  13110656
#       13110656       NaN  13110656
#       17320176       NaN  17320176
#       17320176       NaN  17320176
#       17317728       NaN  17317728
#       17317728       NaN  17317728
#       17323728       NaN  17323728
#       17323600       NaN  17323600
#       17323600       NaN  17323600
#       17322464       NaN  17322464
#       17320048       NaN  17320048
#       17320048       NaN  17320048
#       17321984       NaN  17321984
#       17321936       NaN  17321936
#       17321936       NaN  17321936
#       17323872       NaN  17323872
#       13109984       NaN  13109984
#       13109984       NaN  13109984
#       17327520       NaN  17327520
#       13101408       NaN  13101408
#       13277408       NaN  13277408
#       13283008       NaN  13283008
#       13302064       NaN  13302064
#       13307424       NaN  13307424
#       17506224       NaN  17506224
#       17528160       NaN  17528160
#
#                                                     function_name  task_id
# 26509 12864560  MinimalTFMessageFilter<LaserScan >::sensorCall...    26509
#       12864560  MinimalTFMessageFilter<LaserScan >::sensorCall...    26509
#       17707136  boost::shared_ptr<message_filters::CallbackHel...    26509
#       13100048  MinimalTFMessageFilter<LaserScan >::sensorCall...    26509
#       13100048  MinimalTFMessageFilter<LaserScan >::sensorCall...    26509
#       28362640  boost::shared_ptr<message_filters::CallbackHel...    26509
#       17707184  message_filters::Connection message_filters::S...    26509
#       17707184  boost::shared_ptr<message_filters::CallbackHel...    26509
#       17705200  boost::shared_ptr<message_filters::CallbackHel...    26509
#       13100384  boost::shared_ptr<message_filters::CallbackHel...    26509
#       13100384  message_filters::Connection message_filters::S...    26509
#       13099584  boost::shared_ptr<message_filters::CallbackHel...    26509
#       17693520  message_filters::Connection message_filters::S...    26509
#       17693520  /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...    26509
#       13100320         costmap_2d::LayeredCostmap::updateCallback    26509
#       13100320  message_filters::Connection message_filters::S...    26509
#       17698992  message_filters::Connection message_filters::S...    26509
#       17698992  /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...    26509
#       17696512  boost::shared_ptr<message_filters::CallbackHel...    26509
#       13107216  boost::shared_ptr<message_filters::CallbackHel...    26509
#       13101888  message_filters::Connection message_filters::S...    26509
#       13101888  /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...    26509
#       13049328  message_filters::Connection message_filters::S...    26509
#       13049328  /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...    26509
#       17699584         costmap_2d::LayeredCostmap::updateCallback    26509
#       17699584  message_filters::Connection message_filters::S...    26509
#       17699040  boost::shared_ptr<message_filters::CallbackHel...    26509
#       17699312  boost::shared_ptr<message_filters::CallbackHel...    26509
#       13107168  boost::shared_ptr<message_filters::CallbackHel...    26509
#       17705136  boost::shared_ptr<message_filters::CallbackHel...    26509
# ...                                                           ...      ...
#       28363232                  ros::TopicManager::addSubCallback    26509
#       13110496      message_filters::Subscriber<PointCloud2 >::cb    26509
#       13110496                  ros::TopicManager::addSubCallback    26509
#       13110704  boost::shared_ptr<message_filters::CallbackHel...    26509
#       13110656  /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...    26509
#       13110656  message_filters::Connection message_filters::S...    26509
#       17320176  MinimalTFMessageFilterBase::transformCallbackN...    26509
#       17320176                  ros::TopicManager::addSubCallback    26509
#       17317728  MinimalTFMessageFilterBase::transformCallbackS...    26509
#       17317728                  ros::TopicManager::addSubCallback    26509
#       17323728  boost::shared_ptr<message_filters::CallbackHel...    26509
#       17323600  MinimalTFMessageFilter<PointCloud2 >::sensorCa...    26509
#       17323600  MinimalTFMessageFilter<PointCloud2 >::sensorCa...    26509
#       17322464  boost::shared_ptr<message_filters::CallbackHel...    26509
#       17320048  /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...    26509
#       17320048  message_filters::Connection message_filters::S...    26509
#       17321984  boost::shared_ptr<message_filters::CallbackHel...    26509
#       17321936  boost::shared_ptr<message_filters::CallbackHel...    26509
#       17321936  message_filters::Connection message_filters::S...    26509
#       17323872  boost::shared_ptr<message_filters::CallbackHel...    26509
#       13109984         costmap_2d::LayeredCostmap::updateCallback    26509
#       13109984  message_filters::Connection message_filters::S...    26509
#       17327520  costmap_2d::Costmap2DROS::setUnpaddedRobotFoot...    26509
#       13101408  base_local_planner::OdometryHelperRos::odomCal...    26509
#       13277408  actionlib::ActionServerBase<move_base_msgs::Re...    26509
#       13283008  actionlib::ActionServerBase<move_base_msgs::Re...    26509
#       13302064  actionlib::ActionServerBase<move_base_msgs::Mo...    26509
#       13307424  actionlib::ActionServerBase<move_base_msgs::Mo...    26509
#       17506224  actionlib::ActionServerBase<move_base_msgs::Ob...    26509
#       17528160  actionlib::ActionServerBase<move_base_msgs::Ob...    26509
#
# [136 rows x 4 columns]

# %%
receipt=df.mtrace.query("message_name=='local_costmap/obstacle_layer'")['receipt_time']
receipt - receipt.shift()
# Out:
# 2016-06-21 10:31:16.008143917               NaT
# 2016-06-21 10:31:16.108297235   00:00:00.079315
# 2016-06-21 10:31:16.127322928   00:00:00.040777
# 2016-06-21 10:31:16.167341385   00:00:00.039438
# 2016-06-21 10:31:16.207380094   00:00:00.039633
# 2016-06-21 10:31:16.247395624   00:00:00.040677
# 2016-06-21 10:31:16.287505204   00:00:00.039520
# 2016-06-21 10:31:16.327387047   00:00:00.039720
# 2016-06-21 10:31:16.367515002   00:00:00.040526
# 2016-06-21 10:31:16.407460173   00:00:00.039579
# 2016-06-21 10:31:16.447389179   00:00:00.040649
# 2016-06-21 10:31:16.487307307   00:00:00.039732
# 2016-06-21 10:31:16.527420975   00:00:00.039810
# 2016-06-21 10:31:16.567447202   00:00:00.040591
# 2016-06-21 10:31:16.607366224   00:00:00.039744
# 2016-06-21 10:31:16.647382770   00:00:00.039646
# 2016-06-21 10:31:16.687386880   00:00:00.039738
# 2016-06-21 10:31:16.727373716   00:00:00.040836
# 2016-06-21 10:31:16.767535011   00:00:00.039817
# 2016-06-21 10:31:16.807535814   00:00:00.039725
# 2016-06-21 10:31:16.847381960   00:00:00.039760
# 2016-06-21 10:31:16.887313314   00:00:00.040696
# 2016-06-21 10:31:16.927490550   00:00:00.039691
# 2016-06-21 10:31:16.967419969   00:00:00.039923
# 2016-06-21 10:31:17.007300071   00:00:00.039623
# 2016-06-21 10:31:17.047612905   00:00:00.040492
# 2016-06-21 10:31:17.087346758   00:00:00.039459
# 2016-06-21 10:31:17.127413354   00:00:00.040466
# 2016-06-21 10:31:17.167392192   00:00:00.039834
# 2016-06-21 10:31:17.207382228   00:00:00.039677
#                                       ...
# 2016-06-21 10:31:27.039266538   00:00:00.040601
# 2016-06-21 10:31:27.079273853   00:00:00.039475
# 2016-06-21 10:31:27.119289744   00:00:00.040526
# 2016-06-21 10:31:27.159441962   00:00:00.039751
# 2016-06-21 10:31:27.199235719   00:00:00.039681
# 2016-06-21 10:31:27.239316718   00:00:00.039649
# 2016-06-21 10:31:27.279286299   00:00:00.040588
# 2016-06-21 10:31:27.319322228   00:00:00.039630
# 2016-06-21 10:31:27.359376808   00:00:00.040662
# 2016-06-21 10:31:27.399391586   00:00:00.039684
# 2016-06-21 10:31:27.439469305   00:00:00.039742
# 2016-06-21 10:31:27.479302715   00:00:00.039729
# 2016-06-21 10:31:27.519258238   00:00:00.040799
# 2016-06-21 10:31:27.559359916   00:00:00.039650
# 2016-06-21 10:31:27.599257798   00:00:00.039772
# 2016-06-21 10:31:27.639520228   00:00:00.039737
# 2016-06-21 10:31:27.679316158   00:00:00.040621
# 2016-06-21 10:31:27.719833302   00:00:00.039657
# 2016-06-21 10:31:27.759247478   00:00:00.040035
# 2016-06-21 10:31:27.799235347   00:00:00.040738
# 2016-06-21 10:31:27.839321835   00:00:00.039898
# 2016-06-21 10:31:27.879240807   00:00:00.039494
# 2016-06-21 10:31:27.919453758   00:00:00.039386
# 2016-06-21 10:31:27.959254801   00:00:00.040540
# 2016-06-21 10:31:27.999323853   00:00:00.039549
# 2016-06-21 10:31:28.039244569   00:00:00.040659
# 2016-06-21 10:31:28.079258451   00:00:00.039772
# 2016-06-21 10:31:28.119302205   00:00:00.039482
# 2016-06-21 10:31:28.159393258   00:00:00.040674
# 2016-06-21 10:31:28.199221220   00:00:00.039708
# Name: receipt_time, dtype: timedelta64[ns]

# %%
t_direct=tp.pickle2pd("/home/ingo/Temp/turtlebot-run-29067-local_costmap_no_update-20160512-144411.pickle", map_roscpp)

# %%
plot_delays2(t_direct)

# %%
t_direct2=tp.pickle2pd("/home/ingo/Temp/turtlebot-run-24244-20160512-150009.pickle", map_roscpp)
plot_delays2(t_direct2)

# %%
m=steady.merge(trace_pd.tasks)
m[m['node'] == 'move_base'].groupby("task_name").agg(np.sum)['on_cpu'].plot.pie()
matplotlib.pyplot.savefig("pie.pdf")

# %%
#set(trace_pd.functions.merge(trace_pd.tasks).query("node=='move_base'")['task_name'])
#trace_pd.tasks.query("node=='move_base'")
m.index = m.timestamp
r=m[m['node'] == 'move_base'].groupby("task_name").resample(Milli(100), how=np.sum)
r.index=r.index.droplevel(1)
#r['on_cpu'].plot()

# %%
fns=trace_pd.invocations.merge(trace_pd.tasks).query("node=='move_base'").query("task_name=='SingleThreadedSpinner::spin of '").merge(trace_pd.functions)
fns.index=fns['function_name']
fns.groupby("function_name")["duration"].plot()
# Out:
# function_name
# actionlib::ActionServer<move_base_msgs::MoveBaseAction >::publishStatus                                                                                                                                                                                                                                                                                                                                                               Axes(0.125,0.125;0.775x0.775)
# actionlib::ActionServer<move_base_msgs::ObstacleMonitorAction >::publishStatus                                                                                                                                                                                                                                                                                                                                                        Axes(0.125,0.125;0.775x0.775)
# actionlib::ActionServer<move_base_msgs::RecoveryAction >::publishStatus                                                                                                                                                                                                                                                                                                                                                               Axes(0.125,0.125;0.775x0.775)
# actionlib::ActionServerBase<move_base_msgs::MoveBaseAction >::goalCallback                                                                                                                                                                                                                                                                                                                                                            Axes(0.125,0.125;0.775x0.775)
# base_local_planner::OdometryHelperRos::odomCallback                                                                                                                                                                                                                                                                                                                                                                                   Axes(0.125,0.125;0.775x0.775)
# boost::shared_ptr<message_filters::CallbackHelper1<LaserScan > > message_filters::Signal1<LaserScan >::addCallback<boost::shared_ptr<LaserScan const> const&>                                                                                                                                                                                                                                                                         Axes(0.125,0.125;0.775x0.775)
# costmap_2d::Costmap2DROS::movementCB                                                                                                                                                                                                                                                                                                                                                                                                  Axes(0.125,0.125;0.775x0.775)
# costmap_2d::StaticLayer::incomingMap                                                                                                                                                                                                                                                                                                                                                                                                  Axes(0.125,0.125;0.775x0.775)
# message_filters::CallbackHelper1T<boost::shared_ptr<LaserScan const> const&, LaserScan >::CallbackHelper1T                                                                                                                                                                                                                                                                                                                            Axes(0.125,0.125;0.775x0.775)
# message_filters::Connection message_filters::SimpleFilter<LaserScan >::registerCallback<boost::_bi::bind_t<void, boost::_mfi::mf2<void, costmap_2d::ObstacleLayer, boost::shared_ptr<LaserScan const> const&, boost::shared_ptr<costmap_2d::ObservationBuffer> const&>, boost::_bi::list3<boost::_bi::value<costmap_2d::ObstacleLayer*>, boost::arg<1>, boost::_bi::value<boost::shared_ptr<costmap_2d::ObservationBuffer> > > > >    Axes(0.125,0.125;0.775x0.775)
# message_filters::Subscriber<LaserScan >::cb                                                                                                                                                                                                                                                                                                                                                                                           Axes(0.125,0.125;0.775x0.775)
# ros::TopicManager::addSubCallback                                                                                                                                                                                                                                                                                                                                                                                                     Axes(0.125,0.125;0.775x0.775)
# tf::MessageFilter<LaserScan >::incomingMessage                                                                                                                                                                                                                                                                                                                                                                                        Axes(0.125,0.125;0.775x0.775)
# tf::MessageFilter<LaserScan >::maxRateTimerCallback                                                                                                                                                                                                                                                                                                                                                                                   Axes(0.125,0.125;0.775x0.775)
# tf::MessageFilter<PointCloud2 >::maxRateTimerCallback                                                                                                                                                                                                                                                                                                                                                                                 Axes(0.125,0.125;0.775x0.775)
# Name: duration, dtype: object

# %%
#trace_pd.functions.merge(trace_pd.tasks).query("node=='move_base'").query("task_name=='SingleThreadedSpinner::spin of '").merge(trace_pd.runtime).groupby("function_name").agg(np.sum)['on_cpu'].plot.bar()
#trace_pd.invocations.merge(trace_pd.tasks).query("node=='move_base'").query("task_name=='SingleThreadedSpinner::spin of '").merge(trace_pd.functions).groupby("function_name").agg(np.mean)["cycles"].plot.bar()
fns=trace_pd.invocations.merge(trace_pd.tasks).query("node=='move_base'").query("task_name=='SingleThreadedSpinner::spin of '").merge(trace_pd.functions).groupby("function_name")
means=fns.agg([np.sum, np.mean])
means[("cycles", "sum")]/=1e3
means[("duration", "sum")]/=1e3
del means['callback']
del means['task_id']
errs=fns.std()
count=fns.agg(["count"])["cycles"]
count.index=range(0, len(count))
means.plot.bar(yerr=errs, table=count.T)
#matplotlib.pyplot.savefig("table.pdf")

# %%
trace_pd = tp.pickle2pd("/home/ingo/Temp/auto-20160424-160146.pickle", map_roscpp)

# %%
#trace_pd.invocations.merge(trace_pd.functions).query("node=='move_base'")
#trace_pd.functions.merge(trace_pd.tasks, how="outer", on=['task_id', 'task_id']).query("node=='move_base'")
#set(trace_pd.functions.merge(trace_pd.tasks).query("node=='move_base'")['task_name'])
    #trace_pd.tasks.query("node=='move_base'")
#for row in trace_pd.functions:
#    print(row)
    #if "execute" in row.icol['function_name']:
    #    print(row)
for index, row in trace_pd.functions.iterrows():
    if "execute" in row['function_name']:
        #print(trace_pd.tasks[row['task_id']])
        #print(trace_pd.invocations[row['callback']])
        print(row)
#trace_pd.invocations[139887253391372]
int(0x7F3A0A0C080C)
# Out:
# callback                           139887253391372
# function_name    move_base::MoveBase::executeCycle
# task_id                                      10829
# Name: (10829, 139887253391372), dtype: object
# 139887253391372

# %%
for d in trace_pd.mtrace.query("message_name=='local_costmap/obstacle_layer'")["receipt_time"][0:5]:
    print(trace_pd.)
# Out:
# 2016-04-24 14:01:56.850618880
# 2016-04-24 14:01:57.050718976
# 2016-04-24 14:01:57.250245120
# 2016-04-24 14:01:57.450800128
# 2016-04-24 14:01:57.650768896

# %%
df_all=tp.pickle2pd("/home/ingo/Temp/all.pickle", map_roscpp)

# %%
df_all.tasks.merge(df_all.invocations).query("node=='move_base' and task_id==26816").groupby("callback").agg({'duration': np.mean}).sort_values(by="duration").merge(df_all.functions, left_index=True, right_on="callback", how="outer")
# Out:
#                             duration         callback  \
# 26816 36762560           1396.806738         36762560
#       32287440           1756.099470         32287440
#       47427024           2122.591914         47427024
#       36764656           2170.796690         36764656
#       36772560           2817.852246         36772560
#       36772560           2817.852246         36772560
#       32287392           3098.944085         32287392
#       32287392           3098.944085         32287392
#       47426736           3445.346631         47426736
#       47426736           3445.346631         47426736
#       36764416           3798.261229         36764416
#       36764416           3798.261229         36764416
#       32286896           3912.931136         32286896
#       32288912           5113.128311         32288912
#       32288912           5113.128311         32288912
#       36765216           5256.346092         36765216
#       36768208           7412.442049         36768208
#       36768208           7412.442049         36768208
#       32288864          26785.802237         32288864
#       32370208          28167.392584         32370208
#       32370208          28167.392584         32370208
#       36771712          52370.192080         36771712
#       36764368          53987.130024         36764368
#       36764368          53987.130024         36764368
#       32952912         347258.499730         32952912
#       32952912         347258.499730         32952912
#       139695662610128  364252.447439  139695662610128
#       139695662610128  364252.447439  139695662610128
#       36770224         383994.001617         36770224
#       36770224         383994.001617         36770224
# ...                              ...              ...
#       32317664                   NaN         32317664
#       32317664                   NaN         32317664
#       47427872                   NaN         47427872
#       47427872                   NaN         47427872
#       32286176                   NaN         32286176
#       32286176                   NaN         32286176
#       32292832                   NaN         32292832
#       32292832                   NaN         32292832
#       32290912                   NaN         32290912
#       32286624                   NaN         32286624
#       32286624                   NaN         32286624
#       32291040                   NaN         32291040
#       32291040                   NaN         32291040
#       32391808                   NaN         32391808
#       32391760                   NaN         32391760
#       32391760                   NaN         32391760
#       32391984                   NaN         32391984
#       32391936                   NaN         32391936
#       32391936                   NaN         32391936
#       32289216                   NaN         32289216
#       32391856                   NaN         32391856
#       32391856                   NaN         32391856
#       32401808                   NaN         32401808
#       47444416                   NaN         47444416
#       33237936                   NaN         33237936
#       33107920                   NaN         33107920
#       33133024                   NaN         33133024
#       33149200                   NaN         33149200
#       47481728                   NaN         47481728
#       47484944                   NaN         47484944
#
#                                                            function_name  \
# 26816 36762560         boost::shared_ptr<message_filters::CallbackHel...
#       32287440         boost::shared_ptr<message_filters::CallbackHel...
#       47427024         boost::shared_ptr<message_filters::CallbackHel...
#       36764656         boost::shared_ptr<message_filters::CallbackHel...
#       36772560                costmap_2d::LayeredCostmap::updateCallback
#       36772560         message_filters::Connection message_filters::S...
#       32287392         /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...
#       32287392         message_filters::Connection message_filters::S...
#       47426736         /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...
#       47426736         message_filters::Connection message_filters::S...
#       36764416         /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...
#       36764416         message_filters::Connection message_filters::S...
#       32286896         boost::shared_ptr<message_filters::CallbackHel...
#       32288912                costmap_2d::LayeredCostmap::updateCallback
#       32288912         message_filters::Connection message_filters::S...
#       36765216         boost::shared_ptr<message_filters::CallbackHel...
#       36768208         /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...
#       36768208         message_filters::Connection message_filters::S...
#       32288864         boost::shared_ptr<message_filters::CallbackHel...
#       32370208         boost::shared_ptr<message_filters::CallbackHel...
#       32370208         message_filters::Connection message_filters::S...
#       36771712         boost::shared_ptr<message_filters::CallbackHel...
#       36764368         boost::shared_ptr<message_filters::CallbackHel...
#       36764368         message_filters::Connection message_filters::S...
#       32952912         tf2_ros::MessageFilter<LaserScan >::incomingMe...
#       32952912         tf2_ros::MessageFilter<LaserScan >::incomingMe...
#       139695662610128  tf2_ros::MessageFilter<LaserScan >::incomingMe...
#       139695662610128  tf2_ros::MessageFilter<LaserScan >::incomingMe...
#       36770224         tf2_ros::MessageFilter<LaserScan >::incomingMe...
#       36770224         tf2_ros::MessageFilter<LaserScan >::incomingMe...
# ...                                                                  ...
#       32317664         tf2_ros::TransformListener::subscription_callback
#       32317664                         ros::TopicManager::addSubCallback
#       47427872         tf2_ros::TransformListener::static_subscriptio...
#       47427872                         ros::TopicManager::addSubCallback
#       32286176               message_filters::Subscriber<LaserScan >::cb
#       32286176                         ros::TopicManager::addSubCallback
#       32292832             message_filters::Subscriber<PointCloud2 >::cb
#       32292832                         ros::TopicManager::addSubCallback
#       32290912         boost::shared_ptr<message_filters::CallbackHel...
#       32286624         /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...
#       32286624         message_filters::Connection message_filters::S...
#       32291040         tf2_ros::MessageFilter<PointCloud2 >::incoming...
#       32291040         tf2_ros::MessageFilter<PointCloud2 >::incoming...
#       32391808         boost::shared_ptr<message_filters::CallbackHel...
#       32391760         /home/ingo/src/ros_ws/devel/lib/liblayers.so(+...
#       32391760         message_filters::Connection message_filters::S...
#       32391984         boost::shared_ptr<message_filters::CallbackHel...
#       32391936         boost::shared_ptr<message_filters::CallbackHel...
#       32391936         message_filters::Connection message_filters::S...
#       32289216         boost::shared_ptr<message_filters::CallbackHel...
#       32391856                costmap_2d::LayeredCostmap::updateCallback
#       32391856         message_filters::Connection message_filters::S...
#       32401808         costmap_2d::Costmap2DROS::setUnpaddedRobotFoot...
#       47444416         base_local_planner::OdometryHelperRos::odomCal...
#       33237936         actionlib::ActionServerBase<move_base_msgs::Re...
#       33107920         actionlib::ActionServerBase<move_base_msgs::Re...
#       33133024         actionlib::ActionServerBase<move_base_msgs::Mo...
#       33149200         actionlib::ActionServerBase<move_base_msgs::Mo...
#       47481728         actionlib::ActionServerBase<move_base_msgs::Ob...
#       47484944         actionlib::ActionServerBase<move_base_msgs::Ob...
#
#                        task_id
# 26816 36762560           26816
#       32287440           26816
#       47427024           26816
#       36764656           26816
#       36772560           26816
#       36772560           26816
#       32287392           26816
#       32287392           26816
#       47426736           26816
#       47426736           26816
#       36764416           26816
#       36764416           26816
#       32286896           26816
#       32288912           26816
#       32288912           26816
#       36765216           26816
#       36768208           26816
#       36768208           26816
#       32288864           26816
#       32370208           26816
#       32370208           26816
#       36771712           26816
#       36764368           26816
#       36764368           26816
#       32952912           26816
#       32952912           26816
#       139695662610128    26816
#       139695662610128    26816
#       36770224           26816
#       36770224           26816
# ...                        ...
#       32317664           26816
#       32317664           26816
#       47427872           26816
#       47427872           26816
#       32286176           26816
#       32286176           26816
#       32292832           26816
#       32292832           26816
#       32290912           26816
#       32286624           26816
#       32286624           26816
#       32291040           26816
#       32291040           26816
#       32391808           26816
#       32391760           26816
#       32391760           26816
#       32391984           26816
#       32391936           26816
#       32391936           26816
#       32289216           26816
#       32391856           26816
#       32391856           26816
#       32401808           26816
#       47444416           26816
#       33237936           26816
#       33107920           26816
#       33133024           26816
#       33149200           26816
#       47481728           26816
#       47484944           26816
#
# [120 rows x 4 columns]
